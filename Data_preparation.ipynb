# %%
import pandas as pd
import numpy as np

# %%
ou = pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_ourense.xlsx')
ou.columns = map(lambda x: str(x).lower(), ou.columns)
ou['municipio'] = ou['municipio'].str.upper()
ou.head()
# Out:
#    codigo municipio   ano  superficie total do concello  \
# 0      32   OURENSE  2006                        727341
# 1      32   OURENSE  2007                        727341
# 2      32   OURENSE  2008                        727341
# 3      32   OURENSE  2009                        727341
# 4      32   OURENSE  2010                        727341
#
#    superficie forestal total forestal arborizado  \
# 0                     526766              287187
# 1                     538247              284575
# 2                     538069              285131
# 3                     538187              285390
# 4                     538596              285834
#
#   pasteiro, pasteiro arbustivo e mato  superficie de cultivo e prado  \
# 0                              239578                         125500
# 1                              253673                         116679
# 2                              252938                         116781
# ...

# %%
po= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_pontevedra.xlsx')
po.columns = map(lambda x: str(x).lower(), po.columns)
po['municipio'] = po['municipio'].str.upper()
po.head()
# Out:
#    codigo   municipio   ano superficie total do concello  \
# 0      36  PONTEVEDRA  2006                       449574
# 1      36  PONTEVEDRA  2007                       449574
# 2      36  PONTEVEDRA  2008                       449574
# 3      36  PONTEVEDRA  2009                       449574
# 4      36  PONTEVEDRA  2010                       449574
#
#   superficie forestal total forestal arborizado  \
# 0                    290874              210100
# 1                    293034              216886
# 2                    292309              217669
# 3                    291768              217278
# 4                    291439              217184
#
#   pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 0                               80773                         92097
# 1                               76148                         90615
# 2                               74640                         89859
# ...

# %%
po[po['codigo']==36013]
# Out:
#      codigo municipio   ano superficie total do concello  \
# 504   36013    COVELO  2006                        12531
# 505   36013    COVELO  2007                        12531
# 506   36013    COVELO  2008                        12531
# 507   36013    COVELO  2009                        12531
# 508   36013    COVELO  2010                        12531
# 509   36013    COVELO  2011                        12531
# 510   36013    COVELO  2012                        12531
# 511   36013    COVELO  2013                        12531
# 512   36013    COVELO  2014                        13190
# 513   36013    COVELO  2015                        13190
# 514   36013    COVELO  2016                        13190
# 515   36013    COVELO  2017                        13190
# 516   36013    COVELO  2018                        13190
# 517   36013    COVELO  2019                        13470
#
#     superficie forestal total forestal arborizado  \
# 504                     10348                4133
# ...

# %%
co= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_coruña.xlsx')
co.columns = map(lambda x: str(x).lower(), co.columns)
co['municipio'] = co['municipio'].str.upper()
co.head()
# Out:
#    codigo municipio   ano superficie total do concello  \
# 0      15  A CORUÑA  2006                       795327
# 1      15  A CORUÑA  2007                       795327
# 2      15  A CORUÑA  2008                       795327
# 3      15  A CORUÑA  2009                       795327
# 4      15  A CORUÑA  2010                       795327
#
#   superficie forestal total forestal arborizado  \
# 0                    469084              383689
# 1                    476769              392712
# 2                    474249              391888
# 3                    474170              391521
# 4                    475005              393851
#
#   pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 0                               85395                        219160
# 1                               84057                        215168
# 2                               82361                        216331
# ...

# %%
co[co['codigo']==15045]
# Out:
#       codigo  municipio   ano superficie total do concello  \
# 1568   15045  MAZARICOS  2006                        18727
# 1569   15045  MAZARICOS  2007                        18727
# 1570   15045  MAZARICOS  2008                        18727
# 1571   15045  MAZARICOS  2009                        18727
# 1572   15045  MAZARICOS  2010                        18727
# 1573   15045  MAZARICOS  2011                        18727
# 1574   15045  MAZARICOS  2012                        18727
# 1575   15045  MAZARICOS  2013                        18727
# 1576   15045  MAZARICOS  2014                        18730
# 1577   15045  MAZARICOS  2015                        18730
# 1578   15045  MAZARICOS  2016                        18730
# 1579   15045  MAZARICOS  2017                        18730
# 1580   15045  MAZARICOS  2018                        18730
# 1581   15045  MAZARICOS  2019                        18730
#
#      superficie forestal total forestal arborizado  \
# ...

# %%
lu= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_lugo.xlsx')
lu.columns = map(lambda x: str(x).lower(), lu.columns)
lu['municipio'] = lu['municipio'].str.upper()
lu.head()
# Out:
#    codigo municipio   ano  superficie total do concello  \
# 0      27      LUGO  2006                        985600
# 1      27      LUGO  2007                        985600
# 2      27      LUGO  2008                        985600
# 3      27      LUGO  2009                        985600
# 4      27      LUGO  2010                        985600
#
#    superficie forestal total forestal arborizado  \
# 0                     627295              438944
# 1                     638059              447226
# 2                     636131              448611
# 3                     637676              451587
# 4                     638185              452688
#
#   pasteiro, pasteiro arbustivo e mato  superficie de cultivo e prado  \
# 0                              188351                         284423
# 1                              190833                         277201
# 2                              187521                         278413
# ...

# %%
gal = [co, lu, ou, po]
gal = pd.concat(gal)
gal
# Out:
#       codigo municipio   ano superficie total do concello  \
# 0         15  A CORUÑA  2006                       795327
# 1         15  A CORUÑA  2007                       795327
# 2         15  A CORUÑA  2008                       795327
# 3         15  A CORUÑA  2009                       795327
# 4         15  A CORUÑA  2010                       795327
# ...      ...       ...   ...                          ...
# 1031   36057      VIGO  2015                        10906
# 1032   36057      VIGO  2016                        10906
# 1033   36057      VIGO  2017                        10906
# 1034   36057      VIGO  2018                        10906
# 1035   36057      VIGO  2019                        10906
#
#      superficie forestal total forestal arborizado  \
# 0                       469084              383689
# 1                       476769              392712
# 2                       474249              391888
# 3                       474170              391521
# ...

# %%
gal.dtypes
# Out:
# codigo                                  int64
# municipio                              object
# ano                                     int64
# superficie total do concello           object
# superficie forestal total              object
# forestal arborizado                    object
# pasteiro, pasteiro arbustivo e mato    object
# superficie de cultivo e prado          object
# outras superficies                     object
# dtype: object

# %%
gal['codigo']=gal['codigo'].astype(str)

gal['idprovincia']=gal['codigo'].str[0:2]
gal['idmunicipio']=gal['codigo'].str[2:5]

# %%
gal[gal['municipio']=='COVELO']
# Out:
#     codigo municipio   ano superficie total do concello  \
# 504  36013    COVELO  2006                        12531
# 505  36013    COVELO  2007                        12531
# 506  36013    COVELO  2008                        12531
# 507  36013    COVELO  2009                        12531
# 508  36013    COVELO  2010                        12531
# 509  36013    COVELO  2011                        12531
# 510  36013    COVELO  2012                        12531
# 511  36013    COVELO  2013                        12531
# 512  36013    COVELO  2014                        13190
# 513  36013    COVELO  2015                        13190
# 514  36013    COVELO  2016                        13190
# 515  36013    COVELO  2017                        13190
# 516  36013    COVELO  2018                        13190
# 517  36013    COVELO  2019                        13470
#
#     superficie forestal total forestal arborizado  \
# 504                     10348                4133
# ...

# %%
gal['length'] = gal.codigo.str.len()

# %%
gal[gal['idmunicipio']=='45']
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
gal['codigo']= pd.to_numeric(gal['codigo'], downcast='integer')
gal.dtypes
# Out:
# <ipython-input-312-26c3222dc967>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gal['codigo']= pd.to_numeric(gal['codigo'], downcast='integer')
# codigo                                  int32
# municipio                              object
# ano                                     int64
# superficie total do concello           object
# superficie forestal total              object
# forestal arborizado                    object
# pasteiro, pasteiro arbustivo e mato    object
# superficie de cultivo e prado          object
# outras superficies                     object
# idprovincia                              int8
# idmunicipio                             int16
# length                                  int64
# dtype: object

# %%
gal['idmunicipio']= pd.to_numeric(gal['idmunicipio'], downcast='integer')
gal['idprovincia']= pd.to_numeric(gal['idprovincia'], downcast='integer')
# Out:
# <ipython-input-311-765d9e51fab4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gal['idmunicipio']= pd.to_numeric(gal['idmunicipio'], downcast='integer')
# <ipython-input-311-765d9e51fab4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gal['idprovincia']= pd.to_numeric(gal['idprovincia'], downcast='integer')

# %%
gal[gal['codigo']==36013]
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
prov=gal[gal.length != 5]
prov
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
gal=gal.drop(prov.index, axis=0)
gal.shape
# Out:
# (3024, 12)

# %%
prov.shape
# Out:
# (0, 12)

# %%
gal[gal['codigo']==36013]
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
gal[gal['codigo']==36013]
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
gal[gal['municipio']=='COVELO']
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
df = pd.read_csv('/home/dsc/Galician_fires/fires-all.csv')
dfg = df[df['idcomunidad']==3]
dfg.dtypes
# Out:
# id                   int64
# superficie         float64
# fecha               object
# lat                float64
# lng                float64
# latlng_explicit      int64
# idcomunidad          int64
# idprovincia          int64
# idmunicipio          int64
# municipio           object
# causa                int64
# causa_supuesta     float64
# causa_desc           int64
# muertos            float64
# heridos            float64
# time_ctrl            int64
# time_ext             int64
# personal             int64
# medios               int64
# gastos             float64
# perdidas           float64
# dtype: object

# %%
dfg['ano']=dfg['fecha'].str[0:4]
dfg['ano']= pd.to_numeric(dfg['ano'], downcast='integer')
dfg.dtypes
# Out:
# <ipython-input-159-44d6d0d8867b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['ano']=dfg['fecha'].str[0:4]
# <ipython-input-159-44d6d0d8867b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['ano']= pd.to_numeric(dfg['ano'], downcast='integer')
# id                   int64
# superficie         float64
# fecha               object
# lat                float64
# lng                float64
# latlng_explicit      int64
# idcomunidad          int64
# idprovincia          int64
# ...

# %%
dfg['idprovincia']=dfg['idprovincia'].astype(str)
dfg['idmunicipio']=dfg['idmunicipio'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-01b29f7dd596> in <module>
# ----> 1 gal['idprovincia']=gal['idprovincia'].astype(str)
#       2 gal['idmunicipio']=gal['idmunicipio'].astype(str)
#
# NameError: name 'gal' is not defined

# %%
dfg.idmunicipio.str.len().unique()

# %%
dfg['len']=dfg.idmunicipio.str.len()
dfg

# %%
y=[]
for x in (3-dfg['len']):
    y.append('0'*x)
dfg['ceros']=y

# %%
dfg['ceros'].unique()

# %%
dfg[dfg['ceros']=='00']

# %%
dfg['codigo']=dfg.idprovincia.astype(str)+dfg.ceros.astype(str)+dfg.idmunicipio.astype(str)

# %%
gal.codigo.str.len().unique()

# %%
dfg

# %%
gz = pd.merge(dfg, gal, on = ['idprovincia','idmunicipio','ano'], how ='left')
gz
# Out:
#                id  superficie       fecha        lat       lng  \
# 0      2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1      2001150088        1.50  2001-02-24  42.936918 -9.114350
# 2      2001150090        3.00  2001-02-25  42.643031 -8.939252
# 3      2001150094        1.50  2001-02-25  43.186836 -8.685470
# 4      2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 24583  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 24584  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 24585  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 24586  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 24587  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad  idprovincia  idmunicipio  \
# 0                    1            3           15           22
# 1                    1            3           15           34
# ...

# %%
gal[gal['municipio']=='COVELO']
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
gz.columns
# Out:
# Index(['id', 'superficie', 'fecha', 'lat', 'lng', 'latlng_explicit',
#        'idcomunidad', 'idprovincia', 'idmunicipio', 'municipio_x', 'causa',
#        'causa_supuesta', 'causa_desc', 'muertos', 'heridos', 'time_ctrl',
#        'time_ext', 'personal', 'medios', 'gastos', 'perdidas', 'ano', 'codigo',
#        'municipio_y', 'superficie total do concello',
#        'superficie forestal total', 'forestal arborizado',
#        'pasteiro, pasteiro arbustivo e mato', 'superficie de cultivo e prado',
#        'outras superficies', 'length'],
#       dtype='object')

# %%
gz[['id', 'fecha', 'lat', 'lng',
       'idcomunidad', 'idprovincia', 'idmunicipio', 'municipio_x', 'ano', 'codigo',
       'municipio_y', 'superficie total do concello',
       'superficie forestal total', 'forestal arborizado']][gz['ano']==2008]
# Out:
#                id       fecha        lat       lng  idcomunidad  idprovincia  \
# 16984  2008150001  2008-01-27  42.971510 -7.953572            3           15
# 16985  2008150007  2008-02-10  43.206767 -8.158413            3           15
# 16986  2008150008  2008-02-10  42.971510 -7.953572            3           15
# 16987  2008150011  2008-02-12  42.686091 -8.785263            3           15
# 16988  2008150013  2008-02-13  43.287868 -8.068270            3           15
# ...           ...         ...        ...       ...          ...          ...
# 17691  2008360682  2008-12-24  42.627302 -7.934374            3           36
# 17692  2008360685  2008-12-25  42.679228 -8.257182            3           36
# 17693  2008360688  2008-12-26  42.681691 -8.251026            3           36
# 17694  2008360691  2008-12-26  42.636434 -8.228724            3           36
# 17695  2008360693  2008-12-26  42.340583 -8.309023            3           36
#
# ...

# %%
gz[gz['ano']==2008]
# Out:
#                id  superficie       fecha        lat       lng  \
# 16984  2008150001        5.16  2008-01-27  42.971510 -7.953572
# 16985  2008150007        8.23  2008-02-10  43.206767 -8.158413
# 16986  2008150008        1.00  2008-02-10  42.971510 -7.953572
# 16987  2008150011        1.00  2008-02-12  42.686091 -8.785263
# 16988  2008150013        1.47  2008-02-13  43.287868 -8.068270
# ...           ...         ...         ...        ...       ...
# 17691  2008360682        1.20  2008-12-24  42.627302 -7.934374
# 17692  2008360685        3.00  2008-12-25  42.679228 -8.257182
# 17693  2008360688        1.00  2008-12-26  42.681691 -8.251026
# 17694  2008360691        2.00  2008-12-26  42.636434 -8.228724
# 17695  2008360693        3.00  2008-12-26  42.340583 -8.309023
#
#        latlng_explicit  idcomunidad  idprovincia  idmunicipio   municipio_x  \
# 16984                0            3           15           83        TOQUES
# ...

# %%
gz[gz['municipio_x']=='IRIXOA']
# Out:
#                id  superficie       fecha        lat       lng  \
# 542    2001152541        8.00  2001-12-22  43.297092 -8.051443
# 556    2001152617        2.10  2001-12-25  43.297092 -8.051443
# 2674   2002150010        1.50  2002-02-01  43.262352 -8.093640
# 2754   2002150220        6.00  2002-03-27  43.291096 -8.090415
# 2857   2002150438        1.00  2002-04-10  43.281496 -8.028909
# 2904   2002150548       12.70  2002-04-24  43.281496 -8.028909
# 2917   2002150570        1.50  2002-04-24  43.281496 -8.028909
# 2920   2002150575        3.50  2002-04-25  43.281496 -8.028909
# 5877   2003150147        4.80  2003-03-21  43.319256 -8.107865
# 8638   2004151465        4.00  2004-06-14  43.291096 -8.090415
# 11377  2005151658        1.50  2005-08-13  43.319256 -8.107865
# 16988  2008150013        1.47  2008-02-13  43.287868 -8.068270
# 17858  2009150730        8.86  2009-09-29  43.284730 -8.020587
# 23650  2014150062        2.63  2014-04-18  43.273092 -7.999282
#
# ...

# %%
gal[gal['codigo']==15039]
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
co[co['codigo']==15039]
# Out:
#      codigo municipio   ano superficie total do concello  \
# 392   15039    IRIXOA  2006                         6823
# 393   15039    IRIXOA  2007                         6823
# 394   15039    IRIXOA  2008                         6823
# 395   15039    IRIXOA  2009                         6823
# 396   15039    IRIXOA  2010                         6823
# 397   15039    IRIXOA  2011                         6823
# 398   15039    IRIXOA  2012                         6823
# 399   15039    IRIXOA  2013                         6823
# 400   15039    IRIXOA  2014                         6859
# 401   15039    IRIXOA  2015                         6859
# 402   15039    IRIXOA  2016                         6859
# 403   15039    IRIXOA  2017                         6859
# 404   15039    IRIXOA  2018                         6859
# 405   15039    IRIXOA  2019                         6859
#
#     superficie forestal total forestal arborizado  \
# 392                      4735                4108
# ...

# %%
gz[['municipio_x','municipio_y']]
# Out:
#                  municipio_x         municipio_y
# 0                    CEDEIRA                 NaN
# 1                    DUMBRÍA                 NaN
# 2      POBRA DO CARAMIÑAL, A                 NaN
# 3                   CARBALLO                 NaN
# 4                  MAZARICOS                 NaN
# ...                      ...                 ...
# 24583     SALVATERRA DE MIÑO  SALVATERRA DE MIÑO
# 24584              NEVES, AS            AS NEVES
# 24585                  DOZÓN               DOZÓN
# 24586                 COVELO                 NaN
# 24587                SILLEDA             SILLEDA
#
# [24588 rows x 2 columns]

# %%
dfg[dfg['idmunicipio']==901]
# Out:
#                id  superficie       fecha        lat       lng  \
# 2745   2001270010        2.80  2001-02-19  42.894914 -7.293394
# 2896   2001270624        3.00  2001-09-13  42.953649 -7.188256
# 2926   2001270755        1.00  2001-09-28  42.856677 -7.223983
# 3010   2001270927        2.00  2001-12-24  42.856677 -7.223983
# 3014   2001270932        1.70  2001-12-25  42.928695 -7.237171
# 5423   2001361411        1.20  2001-09-05  42.555417 -8.867273
# 8748   2002152332        2.00  2002-10-20  43.761264 -7.884566
# 9863   2002270571        1.60  2002-07-26  42.897875 -7.253874
# 9864   2002270583        2.50  2002-07-27  42.897875 -7.253874
# 9903   2002270744        7.00  2002-08-17  42.895474 -7.230071
# 9931   2002270843        2.00  2002-08-24  42.895474 -7.230071
# 9934   2002270852        2.25  2002-08-24  42.973745 -7.202909
# 9935   2002270854       12.00  2002-08-24  42.857297 -7.298580
# 9943   2002270865        1.00  2002-08-25  42.857297 -7.298580
# ...

# %%
gz
# Out:
#                id  superficie       fecha        lat       lng  \
# 0      2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1      2001150088        1.50  2001-02-24  42.936918 -9.114350
# 2      2001150090        3.00  2001-02-25  42.643031 -8.939252
# 3      2001150094        1.50  2001-02-25  43.186836 -8.685470
# 4      2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 24583  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 24584  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 24585  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 24586  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 24587  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad  idprovincia  idmunicipio  \
# 0                    1            3           15           22
# 1                    1            3           15           34
# ...

# %%
gz[gz.columns[gz.isna().any()]]
# Out:
#              lat       lng  causa_supuesta  muertos  heridos  gastos  \
# 0      43.703581 -8.038777             1.0      NaN      NaN     NaN
# 1      42.936918 -9.114350             1.0      NaN      NaN     NaN
# 2      42.643031 -8.939252             1.0      NaN      NaN     NaN
# 3      43.186836 -8.685470             1.0      NaN      NaN     NaN
# 4      42.917476 -9.082862             1.0      NaN      NaN     NaN
# ...          ...       ...             ...      ...      ...     ...
# 24583  42.103959 -8.522512             1.0      NaN      NaN  2012.0
# 24584  42.157695 -8.397080             1.0      NaN      NaN  1509.0
# 24585  42.554722 -8.018586             1.0      NaN      NaN  1541.0
# 24586  42.243441 -8.322375             1.0      NaN      NaN  5805.0
# 24587  42.658303 -8.268949             1.0      NaN      NaN   908.0
#
#        perdidas   codigo         municipio_y superficie total do concello  \
# ...
