# %%
import pandas as pd
import numpy as np

# %%
ou = pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_ourense.xlsx')
ou.columns = map(lambda x: str(x).lower(), ou.columns)
ou['municipio'] = ou['municipio'].str.upper()
ou.head()
# Out:
#    codigo municipio   ano  superficie total do concello  \
# 0      32   OURENSE  2006                        727341
# 1      32   OURENSE  2007                        727341
# 2      32   OURENSE  2008                        727341
# 3      32   OURENSE  2009                        727341
# 4      32   OURENSE  2010                        727341
#
#    superficie forestal total forestal arborizado  \
# 0                     526766              287187
# 1                     538247              284575
# 2                     538069              285131
# 3                     538187              285390
# 4                     538596              285834
#
#   pasteiro, pasteiro arbustivo e mato  superficie de cultivo e prado  \
# 0                              239578                         125500
# 1                              253673                         116679
# 2                              252938                         116781
# 3                              252797                         116506
# 4                              252762                         115423
#
#    outras superficies
# 0               75075
# 1               72415
# 2               72491
# 3               72648
# 4               73322

# %%
po= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_pontevedra.xlsx')
po.columns = map(lambda x: str(x).lower(), po.columns)
po['municipio'] = po['municipio'].str.upper()
po.head()
# Out:
#    codigo   municipio   ano superficie total do concello  \
# 0      36  PONTEVEDRA  2006                       449574
# 1      36  PONTEVEDRA  2007                       449574
# 2      36  PONTEVEDRA  2008                       449574
# 3      36  PONTEVEDRA  2009                       449574
# 4      36  PONTEVEDRA  2010                       449574
#
#   superficie forestal total forestal arborizado  \
# 0                    290874              210100
# 1                    293034              216886
# 2                    292309              217669
# 3                    291768              217278
# 4                    291439              217184
#
#   pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 0                               80773                         92097
# 1                               76148                         90615
# 2                               74640                         89859
# 3                               74489                         89510
# 4                               74255                         89030
#
#   outras superficies
# 0              66603
# 1              65924
# 2              67405
# 3              68296
# 4              69105

# %%
po[po['codigo']==36013]
# Out:
#      codigo municipio   ano superficie total do concello  \
# 504   36013    COVELO  2006                        12531
# 505   36013    COVELO  2007                        12531
# 506   36013    COVELO  2008                        12531
# 507   36013    COVELO  2009                        12531
# 508   36013    COVELO  2010                        12531
# 509   36013    COVELO  2011                        12531
# 510   36013    COVELO  2012                        12531
# 511   36013    COVELO  2013                        12531
# 512   36013    COVELO  2014                        13190
# 513   36013    COVELO  2015                        13190
# 514   36013    COVELO  2016                        13190
# 515   36013    COVELO  2017                        13190
# 516   36013    COVELO  2018                        13190
# 517   36013    COVELO  2019                        13470
#
#     superficie forestal total forestal arborizado  \
# 504                     10348                4133
# 505                     10280                3737
# 506                     10318                3785
# 507                     10300                3769
# 508                     10299                3735
# 509                     10300                3727
# 510                      9634                  ..
# 511                      9631                  ..
# 512                     10256                  ..
# 513                     10256                  ..
# 514                     10256                  ..
# 515                     10256                  ..
# 516                     10260                  ..
# 517                     10604                  ..
#
#     pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 504                                6215                           951
# 505                                6543                           893
# 506                                6533                           849
# 507                                6532                           858
# 508                                6564                           854
# 509                                6573                           849
# 510                                  ..                          1649
# 511                                  ..                          1655
# 512                                  ..                          1676
# 513                                  ..                          1677
# 514                                  ..                          1676
# 515                                  ..                          1676
# 516                                  ..                          1674
# 517                                  ..                          1701
#
#     outras superficies
# 504               1232
# 505               1357
# 506               1364
# 507               1372
# 508               1377
# 509               1381
# 510               1247
# 511               1245
# 512               1258
# 513               1258
# 514               1258
# 515               1259
# 516               1257
# 517               1165

# %%
co= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_coruña.xlsx')
co.columns = map(lambda x: str(x).lower(), co.columns)
co['municipio'] = co['municipio'].str.upper()
co.head()
# Out:
#    codigo municipio   ano superficie total do concello  \
# 0      15  A CORUÑA  2006                       795327
# 1      15  A CORUÑA  2007                       795327
# 2      15  A CORUÑA  2008                       795327
# 3      15  A CORUÑA  2009                       795327
# 4      15  A CORUÑA  2010                       795327
#
#   superficie forestal total forestal arborizado  \
# 0                    469084              383689
# 1                    476769              392712
# 2                    474249              391888
# 3                    474170              391521
# 4                    475005              393851
#
#   pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 0                               85395                        219160
# 1                               84057                        215168
# 2                               82361                        216331
# 3                               82649                        216187
# 4                               81154                        214614
#
#   outras superficies
# 0             107083
# 1             103390
# 2             104746
# 3             104970
# 4             105708

# %%
co[co['codigo']==15014]
# Out:
#      codigo              municipio   ano superficie total do concello  \
# 210   15014  CABANA DE BERGANTIÑOS  2006                        10009
# 211   15014  CABANA DE BERGANTIÑOS  2007                        10009
# 212   15014  CABANA DE BERGANTIÑOS  2008                        10009
# 213   15014  CABANA DE BERGANTIÑOS  2009                        10009
# 214   15014  CABANA DE BERGANTIÑOS  2010                        10009
# 215   15014  CABANA DE BERGANTIÑOS  2011                        10009
# 216   15014  CABANA DE BERGANTIÑOS  2012                        10009
# 217   15014  CABANA DE BERGANTIÑOS  2013                        10009
# 218   15014  CABANA DE BERGANTIÑOS  2014                        10023
# 219   15014  CABANA DE BERGANTIÑOS  2015                        10023
# 220   15014  CABANA DE BERGANTIÑOS  2016                        10023
# 221   15014  CABANA DE BERGANTIÑOS  2017                        10023
# 222   15014  CABANA DE BERGANTIÑOS  2018                        10023
# 223   15014  CABANA DE BERGANTIÑOS  2019                        10023
#
#     superficie forestal total forestal arborizado  \
# 210                      6928                6658
# 211                      7029                6740
# 212                      7004                6728
# 213                      7007                6721
# 214                      7035                6759
# 215                      7026                6723
# 216                      7060                  ..
# 217                      7072                  ..
# 218                      7100                  ..
# 219                      7098                  ..
# 220                      7094                  ..
# 221                      7092                  ..
# 222                      7087                  ..
# 223                      7124                  ..
#
#     pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 210                                 270                          2077
# 211                                 290                          2127
# 212                                 277                          2115
# 213                                 286                          2110
# 214                                 276                          2065
# 215                                 303                          2048
# 216                                  ..                          2037
# 217                                  ..                          2014
# 218                                  ..                          2009
# 219                                  ..                          2009
# 220                                  ..                          2008
# 221                                  ..                          2014
# 222                                  ..                          2019
# 223                                  ..                          1970
#
#     outras superficies
# 210               1004
# 211                852
# 212                889
# 213                892
# 214                909
# 215                935
# 216                912
# 217                923
# 218                914
# 219                916
# 220                921
# 221                917
# 222                917
# 223                929

# %%
lu= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_lugo.xlsx')
lu.columns = map(lambda x: str(x).lower(), lu.columns)
lu['municipio'] = lu['municipio'].str.upper()
lu.head()
# Out:
#    codigo municipio   ano  superficie total do concello  \
# 0      27      LUGO  2006                        985600
# 1      27      LUGO  2007                        985600
# 2      27      LUGO  2008                        985600
# 3      27      LUGO  2009                        985600
# 4      27      LUGO  2010                        985600
#
#    superficie forestal total forestal arborizado  \
# 0                     627295              438944
# 1                     638059              447226
# 2                     636131              448611
# 3                     637676              451587
# 4                     638185              452688
#
#   pasteiro, pasteiro arbustivo e mato  superficie de cultivo e prado  \
# 0                              188351                         284423
# 1                              190833                         277201
# 2                              187521                         278413
# 3                              186089                         276677
# 4                              185498                         276133
#
#    outras superficies
# 0               73882
# 1               70340
# 2               71056
# 3               71247
# 4               71282

# %%
gal = [co, lu, ou, po]
gal = pd.concat(gal)
gal
# Out:
#       codigo municipio   ano superficie total do concello  \
# 0         15  A CORUÑA  2006                       795327
# 1         15  A CORUÑA  2007                       795327
# 2         15  A CORUÑA  2008                       795327
# 3         15  A CORUÑA  2009                       795327
# 4         15  A CORUÑA  2010                       795327
# ...      ...       ...   ...                          ...
# 1031   36057      VIGO  2015                        10906
# 1032   36057      VIGO  2016                        10906
# 1033   36057      VIGO  2017                        10906
# 1034   36057      VIGO  2018                        10906
# 1035   36057      VIGO  2019                        10906
#
#      superficie forestal total forestal arborizado  \
# 0                       469084              383689
# 1                       476769              392712
# 2                       474249              391888
# 3                       474170              391521
# 4                       475005              393851
# ...                        ...                 ...
# 1031                      3731                  ..
# 1032                      3727                  ..
# 1033                      3728                  ..
# 1034                      3728                  ..
# 1035                      3708                  ..
#
#      pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 0                                  85395                        219160
# 1                                  84057                        215168
# 2                                  82361                        216331
# 3                                  82649                        216187
# 4                                  81154                        214614
# ...                                  ...                           ...
# 1031                                  ..                          1316
# 1032                                  ..                          1315
# 1033                                  ..                          1314
# 1034                                  ..                          1312
# 1035                                  ..                          1314
#
#      outras superficies
# 0                107083
# 1                103390
# 2                104746
# 3                104970
# 4                105708
# ...                 ...
# 1031               5859
# 1032               5864
# 1033               5864
# 1034               5865
# 1035               5883
#
# [5236 rows x 9 columns]

# %%
gal['codigo'].nunique()
# Out:
# 374

# %%
gal.dtypes
# Out:
# codigo                                  int64
# municipio                              object
# ano                                     int64
# superficie total do concello           object
# superficie forestal total              object
# forestal arborizado                    object
# pasteiro, pasteiro arbustivo e mato    object
# superficie de cultivo e prado          object
# outras superficies                     object
# dtype: object

# %%
gal['codigo_str']=gal['codigo'].astype(str)
gal['length'] = gal.codigo_str.str.len()

# %%
#gal['codigo']= pd.to_numeric(gal['codigo'], downcast='integer')
gal.dtypes
# Out:
# codigo                                  int64
# municipio                              object
# ano                                     int64
# superficie total do concello           object
# superficie forestal total              object
# forestal arborizado                    object
# pasteiro, pasteiro arbustivo e mato    object
# superficie de cultivo e prado          object
# outras superficies                     object
# codigo_str                             object
# length                                  int64
# dtype: object

# %%
prov=gal[gal.length != 5]
gal=gal[gal['length']==5]
gal.shape
# Out:
# (4438, 11)

# %%
prov['codigo'].unique()
# Out:
# array([  15, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510,
#        1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518,   27, 2701, 2702,
#        2703, 2704, 2705, 2706, 2707, 2708, 2709, 2710, 2711, 2712, 2713,
#          32, 3201, 3202, 3203, 3204, 3205, 3206, 3207, 3208, 3209, 3210,
#        3211, 3212,   36, 3601, 3602, 3603, 3604, 3605, 3606, 3607, 3608,
#        3609, 3610])

# %%
gal['codigo'].unique()
# Out:
# array([15006, 15010, 15066, 15085, 15011, 15067, 15072, 15073, 15007,
#        15056, 15014, 15019, 15029, 15041, 15040, 15043, 15068, 15003,
#        15009, 15026, 15027, 15032, 15039, 15048, 15063, 15902, 15064,
#        15091, 15090, 15001, 15005, 15008, 15017, 15021, 15030, 15031,
#        15058, 15075, 15015, 15018, 15050, 15069, 15070, 15004, 15022,
#        15035, 15036, 15049, 15051, 15054, 15055, 15076, 15081, 15087,
#        15023, 15028, 15034, 15037, 15052, 15020, 15053, 15042, 15057,
#        15062, 15071, 15024, 15038, 15047, 15059, 15060, 15084, 15086,
#        15901, 15025, 15044, 15061, 15002, 15012, 15013, 15078, 15082,
#        15088, 15089, 15033, 15065, 15074, 15046, 15079, 15080, 15083,
#        15016, 15092, 15093, 15045, 15077, 27901, 27006, 27012, 27034,
#        27037, 27045, 27009, 27016, 27060, 27004, 27018, 27035, 27011,
#        27014, 27020, 27023, 27028, 27039, 27049, 27056, 27002, 27902,
#        27019, 27027, 27030, 27063, 27013, 27038, 27064, 27066, 27025,
#        27005, 27048, 27051, 27061, 27029, 27046, 27053, 27054, 27017,
#        27050, 27052, 27024, 27026, 27042, 27043, 27055, 27057, 27062,
#        27001, 27007, 27010, 27015, 27022, 27033, 27044, 27065, 27021,
#        27008, 27031, 27041, 27047, 27058, 27059, 27003, 27032, 27040,
#        32001, 32007, 32043, 32055, 32036, 32037, 32006, 32030, 32041,
#        32042, 32051, 32011, 32013, 32019, 32035, 32045, 32061, 32065,
#        32074, 32076, 32005, 32012, 32016, 32062, 32067, 32077, 32078,
#        32082, 32089, 32090, 32032, 32002, 32008, 32026, 32031, 32052,
#        32054, 32058, 32059, 32075, 32079, 32081, 32087, 32003, 32004,
#        32010, 32018, 32022, 32025, 32027, 32040, 32046, 32069, 32023,
#        32049, 32057, 32080, 32014, 32020, 32024, 32033, 32047, 32056,
#        32064, 32066, 32068, 32084, 32029, 32044, 32063, 32070, 32009,
#        32015, 32017, 32038, 32060, 32072, 32073, 32083, 32088, 32021,
#        32028, 32039, 32050, 32053, 32071, 32085, 32091, 32034, 32048,
#        32086, 32092, 36023, 36036, 36048, 36054, 36055, 36005, 36010,
#        36015, 36032, 36044, 36040, 36056, 36030, 36031, 36034, 36042,
#        36050, 36020, 36016, 36024, 36047, 36052, 36059, 36004, 36008,
#        36026, 36029, 36001, 36009, 36013, 36014, 36002, 36007, 36902,
#        36012, 36025, 36041, 36043, 36038, 36058, 36006, 36022, 36901,
#        36027, 36028, 36046, 36051, 36060, 36061, 36011, 36017, 36018,
#        36003, 36019, 36021, 36033, 36035, 36037, 36039, 36045, 36049,
#        36053, 36057])

# %%
df = pd.read_csv('/home/dsc/Galician_fires/fires-all.csv')
dfg = df[df['idcomunidad']==3]
dfg.dtypes
# Out:
# id                   int64
# superficie         float64
# fecha               object
# lat                float64
# lng                float64
# latlng_explicit      int64
# idcomunidad          int64
# idprovincia          int64
# idmunicipio          int64
# municipio           object
# causa                int64
# causa_supuesta     float64
# causa_desc           int64
# muertos            float64
# heridos            float64
# time_ctrl            int64
# time_ext             int64
# personal             int64
# medios               int64
# gastos             float64
# perdidas           float64
# dtype: object

# %%
dfg['ano']=dfg['fecha'].str[0:4]
dfg['ano']= pd.to_numeric(dfg['ano'], downcast='integer')
dfg.dtypes
# Out:
# <ipython-input-258-44d6d0d8867b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['ano']=dfg['fecha'].str[0:4]
# <ipython-input-258-44d6d0d8867b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['ano']= pd.to_numeric(dfg['ano'], downcast='integer')
# id                   int64
# superficie         float64
# fecha               object
# lat                float64
# lng                float64
# latlng_explicit      int64
# idcomunidad          int64
# idprovincia          int64
# idmunicipio          int64
# municipio           object
# causa                int64
# causa_supuesta     float64
# causa_desc           int64
# muertos            float64
# heridos            float64
# time_ctrl            int64
# time_ext             int64
# personal             int64
# medios               int64
# gastos             float64
# perdidas           float64
# ano                  int16
# dtype: object

# %%
dfg['idprovincia']=dfg['idprovincia'].astype(str)
dfg['idmunicipio']=dfg['idmunicipio'].astype(str)
# Out:
# <ipython-input-259-6b142f39d272>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['idprovincia']=dfg['idprovincia'].astype(str)
# <ipython-input-259-6b142f39d272>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['idmunicipio']=dfg['idmunicipio'].astype(str)

# %%
dfg.idmunicipio.str.len().unique()
# Out:
# array([2, 1, 3])

# %%
dfg['len']=dfg.idmunicipio.str.len()
dfg
# Out:
# <ipython-input-261-b629f5aa97be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['len']=dfg.idmunicipio.str.len()
#                id  superficie       fecha        lat       lng  \
# 1202   2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1203   2001150088        1.50  2001-02-24  42.936918 -9.114350
# 1204   2001150090        3.00  2001-02-25  42.643031 -8.939252
# 1205   2001150094        1.50  2001-02-25  43.186836 -8.685470
# 1206   2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 81478  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 81479  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 81480  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 81481  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 81482  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio  \
# 1202                 1            3          15          22
# 1203                 1            3          15          34
# 1204                 1            3          15          67
# 1205                 1            3          15          19
# 1206                 1            3          15          45
# ...                ...          ...         ...         ...
# 81478                1            3          36          50
# 81479                1            3          36          34
# 81480                1            3          36          16
# 81481                1            3          36          13
# 81482                1            3          36          52
#
#                    municipio  ...  muertos  heridos  time_ctrl  time_ext  \
# 1202                 CEDEIRA  ...      NaN      NaN        235       270
# 1203                 DUMBRÍA  ...      NaN      NaN        470       530
# 1204   POBRA DO CARAMIÑAL, A  ...      NaN      NaN        185       220
# 1205                CARBALLO  ...      NaN      NaN        125       135
# 1206               MAZARICOS  ...      NaN      NaN       1050      1051
# ...                      ...  ...      ...      ...        ...       ...
# 81478     SALVATERRA DE MIÑO  ...      NaN      NaN         92       486
# 81479              NEVES, AS  ...      NaN      NaN        404       420
# 81480                  DOZÓN  ...      NaN      NaN         87       194
# 81481                 COVELO  ...      NaN      NaN         89       428
# 81482                SILLEDA  ...      NaN      NaN         70        85
#
#        personal  medios  gastos  perdidas   ano  len
# 1202         14       2     NaN    7013.0  2001    2
# 1203         14       1     NaN    1497.0  2001    2
# 1204         14       3     NaN    1882.0  2001    2
# 1205          5       0     NaN    1028.0  2001    2
# 1206         14       1     NaN    3119.0  2001    2
# ...         ...     ...     ...       ...   ...  ...
# 81478        16       3  2012.0    6198.0  2015    2
# 81479        15       1  1509.0     430.0  2015    2
# 81480        18       3  1541.0       0.0  2015    2
# 81481        21       4  5805.0       0.0  2015    2
# 81482         7       0   908.0       0.0  2015    2
#
# [24587 rows x 23 columns]

# %%
y=[]
for x in (3-dfg['len']):
    y.append('0'*x)
dfg['ceros']=y
# Out:
# <ipython-input-262-298c8d34b603>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['ceros']=y

# %%
dfg['ceros'].unique()
# Out:
# array(['0', '00', ''], dtype=object)

# %%
dfg[dfg['ceros']=='']
# Out:
#                id  superficie       fecha        lat       lng  \
# 2745   2001270010        2.80  2001-02-19  42.894914 -7.293394
# 2896   2001270624        3.00  2001-09-13  42.953649 -7.188256
# 2926   2001270755        1.00  2001-09-28  42.856677 -7.223983
# 3010   2001270927        2.00  2001-12-24  42.856677 -7.223983
# 3014   2001270932        1.70  2001-12-25  42.928695 -7.237171
# ...           ...         ...         ...        ...       ...
# 76593  2014320100      235.00  2014-05-05  42.508042 -6.974919
# 79866  2015270302        4.00  2015-08-04  42.919836 -7.249615
# 79867  2015270311        1.00  2015-08-06  42.907172 -7.236474
# 79875  2015270366        1.00  2015-08-12  42.993221 -6.880362
# 80416  2015320921      314.14  2015-08-23        NaN       NaN
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio       municipio  \
# 2745                 1            3          27         901         BARALLA
# 2896                 1            3          27         901         BARALLA
# 2926                 1            3          27         901         BARALLA
# 3010                 1            3          27         901         BARALLA
# 3014                 1            3          27         901         BARALLA
# ...                ...          ...         ...         ...             ...
# 76593                1            3          32         999  OTRA PROVINCIA
# 79866                1            3          27         901         BARALLA
# 79867                1            3          27         901         BARALLA
# 79875                1            3          27         999  OTRA PROVINCIA
# 80416                0            3          32         998        PORTUGAL
#
#        ...  heridos  time_ctrl  time_ext  personal  medios  gastos  perdidas  \
# 2745   ...      NaN         90       120        10       1     NaN    4958.0
# 2896   ...      NaN        195       245         6       3     NaN       NaN
# 2926   ...      NaN         85       240         6       1     NaN       NaN
# 3010   ...      NaN        205       240         7       0     NaN       NaN
# 3014   ...      NaN        100       110         4       1     6.0       0.0
# ...    ...      ...        ...       ...       ...     ...     ...       ...
# 76593  ...      NaN       1808      2780       142      18     NaN   38782.0
# 79866  ...      NaN        201       466        53      13     NaN   18998.0
# 79867  ...      NaN        236       640        54      15     NaN       0.0
# 79875  ...      NaN        383       868        36       3     NaN    7316.0
# 80416  ...      NaN       3050      4483       141      34     NaN  275065.0
#
#         ano  len  ceros
# 2745   2001    3
# 2896   2001    3
# 2926   2001    3
# 3010   2001    3
# 3014   2001    3
# ...     ...  ...    ...
# 76593  2014    3
# 79866  2015    3
# 79867  2015    3
# 79875  2015    3
# 80416  2015    3
#
# [93 rows x 24 columns]

# %%
dfg['codigo']=dfg.idprovincia.astype(str)+dfg.ceros.astype(str)+dfg.idmunicipio.astype(str)
# Out:
# <ipython-input-265-d6ff3fdfc5d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['codigo']=dfg.idprovincia.astype(str)+dfg.ceros.astype(str)+dfg.idmunicipio.astype(str)

# %%
dfg.codigo.str.len().unique()
# Out:
# array([5])

# %%
dfg['codigo'].nunique()
# Out:
# 319

# %%
dfg[dfg['municipio']=='ARANGA']
# Out:
#                id  superficie       fecha        lat       lng  \
# 1220   2001150227        1.50  2001-04-17  43.244306 -8.079977
# 1253   2001150337        4.50  2001-05-19  43.204208 -8.088987
# 8078   2002150103        1.50  2002-03-10  43.275921 -7.963077
# 8098   2002150144       10.00  2002-03-23  43.199782 -8.034514
# 8103   2002150158        5.00  2002-03-24  43.275921 -7.963077
# ...           ...         ...         ...        ...       ...
# 75895  2014150207        1.01  2014-07-29  43.263033 -7.990008
# 75898  2014150221        1.55  2014-08-16  43.233580 -7.994214
# 75900  2014150258        2.42  2014-08-25  43.227990 -8.022407
# 79207  2015150074        1.80  2015-04-06  43.244640 -7.982170
# 79234  2015150187        3.51  2015-06-17  43.233759 -7.982807
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio municipio  ...  \
# 1220                 1            3          15           3    ARANGA  ...
# 1253                 1            3          15           3    ARANGA  ...
# 8078                 1            3          15           3    ARANGA  ...
# 8098                 1            3          15           3    ARANGA  ...
# 8103                 1            3          15           3    ARANGA  ...
# ...                ...          ...         ...         ...       ...  ...
# 75895                1            3          15           3    ARANGA  ...
# 75898                1            3          15           3    ARANGA  ...
# 75900                1            3          15           3    ARANGA  ...
# 79207                1            3          15           3    ARANGA  ...
# 79234                1            3          15           3    ARANGA  ...
#
#        time_ctrl  time_ext  personal  medios  gastos  perdidas   ano  len  \
# 1220         125       135         9       1     NaN    1857.0  2001    1
# 1253         320       550        24       1     NaN    5030.0  2001    1
# 8078         195       310         4       1     NaN       NaN  2002    1
# 8098         105       150         6       1     NaN       NaN  2002    1
# 8103         290       350         5       0     NaN       NaN  2002    1
# ...          ...       ...       ...     ...     ...       ...   ...  ...
# 75895        139       214        39       6     NaN      33.0  2014    1
# 75898        134       200        23       3     NaN       NaN  2014    1
# 75900         70       255        15       6     NaN    6311.0  2014    1
# 79207        115       215        18       4     NaN       NaN  2015    1
# 79234        372       517        13       2     NaN   11214.0  2015    1
#
#        ceros  codigo
# 1220      00   15003
# 1253      00   15003
# 8078      00   15003
# 8098      00   15003
# 8103      00   15003
# ...      ...     ...
# 75895     00   15003
# 75898     00   15003
# 75900     00   15003
# 79207     00   15003
# 79234     00   15003
#
# [126 rows x 25 columns]

# %%
dfg.dtypes
# Out:
# id                   int64
# superficie         float64
# fecha               object
# lat                float64
# lng                float64
# latlng_explicit      int64
# idcomunidad          int64
# idprovincia         object
# idmunicipio         object
# municipio           object
# causa                int64
# causa_supuesta     float64
# causa_desc           int64
# muertos            float64
# heridos            float64
# time_ctrl            int64
# time_ext             int64
# personal             int64
# medios               int64
# gastos             float64
# perdidas           float64
# ano                  int16
# len                  int64
# ceros               object
# codigo              object
# dtype: object

# %%
dfg['codigo']= pd.to_numeric(dfg['codigo'], downcast='integer')
# Out:
# <ipython-input-270-95e879571f9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['codigo']= pd.to_numeric(dfg['codigo'], downcast='integer')

# %%
dfg.dtypes, gal.dtypes
# Out:
# (id                   int64
#  superficie         float64
#  fecha               object
#  lat                float64
#  lng                float64
#  latlng_explicit      int64
#  idcomunidad          int64
#  idprovincia         object
#  idmunicipio         object
#  municipio           object
#  causa                int64
#  causa_supuesta     float64
#  causa_desc           int64
#  muertos            float64
#  heridos            float64
#  time_ctrl            int64
#  time_ext             int64
#  personal             int64
#  medios               int64
#  gastos             float64
#  perdidas           float64
#  ano                  int16
#  len                  int64
#  ceros               object
#  codigo               int32
#  dtype: object,
#  codigo                                  int64
#  municipio                              object
#  ano                                     int64
#  superficie total do concello           object
#  superficie forestal total              object
#  forestal arborizado                    object
#  pasteiro, pasteiro arbustivo e mato    object
#  superficie de cultivo e prado          object
#  outras superficies                     object
#  codigo_str                             object
#  length                                  int64
#  dtype: object)

# %%
gz = pd.merge(dfg, gal, on = ['ano','codigo'], how ='left')
gz
# Out:
#                id  superficie       fecha        lat       lng  \
# 0      2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1      2001150088        1.50  2001-02-24  42.936918 -9.114350
# 2      2001150090        3.00  2001-02-25  42.643031 -8.939252
# 3      2001150094        1.50  2001-02-25  43.186836 -8.685470
# 4      2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 24582  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 24583  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 24584  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 24585  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 24586  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio  \
# 0                    1            3          15          22
# 1                    1            3          15          34
# 2                    1            3          15          67
# 3                    1            3          15          19
# 4                    1            3          15          45
# ...                ...          ...         ...         ...
# 24582                1            3          36          50
# 24583                1            3          36          34
# 24584                1            3          36          16
# 24585                1            3          36          13
# 24586                1            3          36          52
#
#                  municipio_x  ...  codigo         municipio_y  \
# 0                    CEDEIRA  ...   15022                 NaN
# 1                    DUMBRÍA  ...   15034                 NaN
# 2      POBRA DO CARAMIÑAL, A  ...   15067                 NaN
# 3                   CARBALLO  ...   15019                 NaN
# 4                  MAZARICOS  ...   15045                 NaN
# ...                      ...  ...     ...                 ...
# 24582     SALVATERRA DE MIÑO  ...   36050  SALVATERRA DE MIÑO
# 24583              NEVES, AS  ...   36034            AS NEVES
# 24584                  DOZÓN  ...   36016               DOZÓN
# 24585                 COVELO  ...   36013              COVELO
# 24586                SILLEDA  ...   36052             SILLEDA
#
#        superficie total do concello  superficie forestal total  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 24582                          6254                       3481
# 24583                          6550                       4580
# 24584                          7423                       4702
# 24585                         13190                      10256
# 24586                         16796                       7443
#
#        forestal arborizado  pasteiro, pasteiro arbustivo e mato  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
# ...                    ...                                  ...
# 24582                   ..                                   ..
# 24583                   ..                                   ..
# 24584                   ..                                   ..
# 24585                   ..                                   ..
# 24586                   ..                                   ..
#
#        superficie de cultivo e prado  outras superficies  codigo_str  length
# 0                                NaN                 NaN         NaN     NaN
# 1                                NaN                 NaN         NaN     NaN
# 2                                NaN                 NaN         NaN     NaN
# 3                                NaN                 NaN         NaN     NaN
# 4                                NaN                 NaN         NaN     NaN
# ...                              ...                 ...         ...     ...
# 24582                           1258                1515       36050     5.0
# 24583                            774                1196       36034     5.0
# 24584                           2222                 499       36016     5.0
# 24585                           1677                1258       36013     5.0
# 24586                           6867                2486       36052     5.0
#
# [24587 rows x 34 columns]

# %%
gz.columns
# Out:
# Index(['id', 'superficie', 'fecha', 'lat', 'lng', 'latlng_explicit',
#        'idcomunidad', 'idprovincia', 'idmunicipio', 'municipio_x', 'causa',
#        'causa_supuesta', 'causa_desc', 'muertos', 'heridos', 'time_ctrl',
#        'time_ext', 'personal', 'medios', 'gastos', 'perdidas', 'ano', 'len',
#        'ceros', 'codigo', 'municipio_y', 'superficie total do concello',
#        'superficie forestal total', 'forestal arborizado',
#        'pasteiro, pasteiro arbustivo e mato', 'superficie de cultivo e prado',
#        'outras superficies', 'codigo_str', 'length'],
#       dtype='object')

# %%
gz_dosmilseis=gz[gz['ano']>2005]
gz_dosmilseis[gz_dosmilseis['municipio_y'].isnull()]['codigo'].unique()
# Out:
# array([32998, 15999, 32999, 27999], dtype=int32)

# %%
gz.to_csv('fusion_1.csv')

# %%
gz_dosmilseis[['id','codigo','idprovincia','municipio_x','superficie', 'fecha','ano', 'lat', 'lng','time_ctrl',
       'time_ext', 'personal', 'medios','gastos', 'superficie total do concello',
       'superficie forestal total', 'forestal arborizado',
       'pasteiro, pasteiro arbustivo e mato', 'superficie de cultivo e prado',
       'outras superficies']]
# Out:
#                id  codigo             municipio_x  superficie       fecha  \
# 14139  2006150002   15034                 DUMBRÍA       25.00  2006-01-26
# 14140  2006150003   15023                     CEE        7.50  2006-01-27
# 14141  2006150006   15034                 DUMBRÍA        4.50  2006-01-27
# 14142  2006150009   15043  MALPICA DE BERGANTIÑOS        2.00  2006-01-30
# 14143  2006150013   15083                  TOQUES        2.00  2006-02-02
# ...           ...     ...                     ...         ...         ...
# 24582  2015360747   36050      SALVATERRA DE MIÑO        1.45  2015-09-06
# 24583  2015360751   36034               NEVES, AS        1.00  2015-09-06
# 24584  2015360770   36016                   DOZÓN        5.94  2015-09-08
# 24585  2015360794   36013                  COVELO        3.20  2015-09-28
# 24586  2015360819   36052                 SILLEDA        2.26  2015-12-27
#
#         ano        lat       lng  time_ctrl  time_ext  personal  medios  \
# 14139  2006  42.975410 -9.119204        345       370        21       3
# 14140  2006  42.953631 -9.166422        110       165        14       2
# 14141  2006  43.044329 -9.116182        100       130        16       3
# 14142  2006  43.338796 -8.840326        102       112         6       1
# 14143  2006  42.991186 -7.998102        115       185        11       1
# ...     ...        ...       ...        ...       ...       ...     ...
# 24582  2015  42.103959 -8.522512         92       486        16       3
# 24583  2015  42.157695 -8.397080        404       420        15       1
# 24584  2015  42.554722 -8.018586         87       194        18       3
# 24585  2015  42.243441 -8.322375         89       428        21       4
# 24586  2015  42.658303 -8.268949         70        85         7       0
#
#        gastos superficie total do concello superficie forestal total  \
# 14139     NaN                        12470                      7630
# 14140     NaN                         5749                      4289
# 14141     NaN                        12470                      7630
# 14142     NaN                         6142                      3367
# 14143     NaN                         7792                      5705
# ...       ...                          ...                       ...
# 24582  2012.0                         6254                      3481
# 24583  1509.0                         6550                      4580
# 24584  1541.0                         7423                      4702
# 24585  5805.0                        13190                     10256
# 24586   908.0                        16796                      7443
#
#       forestal arborizado pasteiro, pasteiro arbustivo e mato  \
# 14139                5339                                2291
# 14140                3888                                 401
# 14141                5339                                2291
# 14142                2447                                 921
# 14143                 970                                4736
# ...                   ...                                 ...
# 24582                  ..                                  ..
# 24583                  ..                                  ..
# 24584                  ..                                  ..
# 24585                  ..                                  ..
# 24586                  ..                                  ..
#
#       superficie de cultivo e prado outras superficies
# 14139                          2692               2147
# 14140                          1094                366
# 14141                          2692               2147
# 14142                          1767               1008
# 14143                          2076                 10
# ...                             ...                ...
# 24582                          1258               1515
# 24583                           774               1196
# 24584                          2222                499
# 24585                          1677               1258
# 24586                          6867               2486
#
# [10448 rows x 19 columns]
