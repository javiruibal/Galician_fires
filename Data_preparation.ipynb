# %%
import pandas as pd
import numpy as np

# %%
ou = pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_ourense.xlsx')
ou.columns = map(lambda x: str(x).lower(), ou.columns)
ou['municipio'] = ou['municipio'].str.upper()
ou.head()
# Out:
#    codigo municipio   ano  superficie total do concello  \
# 0      32   OURENSE  2006                        727341
# 1      32   OURENSE  2007                        727341
# 2      32   OURENSE  2008                        727341
# 3      32   OURENSE  2009                        727341
# 4      32   OURENSE  2010                        727341
#
#    superficie forestal total forestal arborizado  \
# 0                     526766              287187
# 1                     538247              284575
# 2                     538069              285131
# 3                     538187              285390
# 4                     538596              285834
#
#   pasteiro, pasteiro arbustivo e mato  superficie de cultivo e prado  \
# 0                              239578                         125500
# 1                              253673                         116679
# 2                              252938                         116781
# 3                              252797                         116506
# 4                              252762                         115423
#
#    outras superficies
# 0               75075
# 1               72415
# 2               72491
# 3               72648
# 4               73322

# %%
po= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_pontevedra.xlsx')
po.columns = map(lambda x: str(x).lower(), po.columns)
po['municipio'] = po['municipio'].str.upper()
po.head()
# Out:
#    codigo   municipio   ano superficie total do concello  \
# 0      36  PONTEVEDRA  2006                       449574
# 1      36  PONTEVEDRA  2007                       449574
# 2      36  PONTEVEDRA  2008                       449574
# 3      36  PONTEVEDRA  2009                       449574
# 4      36  PONTEVEDRA  2010                       449574
#
#   superficie forestal total forestal arborizado  \
# 0                    290874              210100
# 1                    293034              216886
# 2                    292309              217669
# 3                    291768              217278
# 4                    291439              217184
#
#   pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 0                               80773                         92097
# 1                               76148                         90615
# 2                               74640                         89859
# 3                               74489                         89510
# 4                               74255                         89030
#
#   outras superficies
# 0              66603
# 1              65924
# 2              67405
# 3              68296
# 4              69105

# %%
po[po['codigo']==36013]
# Out:
#      codigo municipio   ano superficie total do concello  \
# 504   36013    COVELO  2006                        12531
# 505   36013    COVELO  2007                        12531
# 506   36013    COVELO  2008                        12531
# 507   36013    COVELO  2009                        12531
# 508   36013    COVELO  2010                        12531
# 509   36013    COVELO  2011                        12531
# 510   36013    COVELO  2012                        12531
# 511   36013    COVELO  2013                        12531
# 512   36013    COVELO  2014                        13190
# 513   36013    COVELO  2015                        13190
# 514   36013    COVELO  2016                        13190
# 515   36013    COVELO  2017                        13190
# 516   36013    COVELO  2018                        13190
# 517   36013    COVELO  2019                        13470
#
#     superficie forestal total forestal arborizado  \
# 504                     10348                4133
# 505                     10280                3737
# 506                     10318                3785
# 507                     10300                3769
# 508                     10299                3735
# 509                     10300                3727
# 510                      9634                  ..
# 511                      9631                  ..
# 512                     10256                  ..
# 513                     10256                  ..
# 514                     10256                  ..
# 515                     10256                  ..
# 516                     10260                  ..
# 517                     10604                  ..
#
#     pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 504                                6215                           951
# 505                                6543                           893
# 506                                6533                           849
# 507                                6532                           858
# 508                                6564                           854
# 509                                6573                           849
# 510                                  ..                          1649
# 511                                  ..                          1655
# 512                                  ..                          1676
# 513                                  ..                          1677
# 514                                  ..                          1676
# 515                                  ..                          1676
# 516                                  ..                          1674
# 517                                  ..                          1701
#
#     outras superficies
# 504               1232
# 505               1357
# 506               1364
# 507               1372
# 508               1377
# 509               1381
# 510               1247
# 511               1245
# 512               1258
# 513               1258
# 514               1258
# 515               1259
# 516               1257
# 517               1165

# %%
co= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_coruña.xlsx')
co.columns = map(lambda x: str(x).lower(), co.columns)
co['municipio'] = co['municipio'].str.upper()
co.head()
# Out:
#    codigo municipio   ano superficie total do concello  \
# 0      15  A CORUÑA  2006                       795327
# 1      15  A CORUÑA  2007                       795327
# 2      15  A CORUÑA  2008                       795327
# 3      15  A CORUÑA  2009                       795327
# 4      15  A CORUÑA  2010                       795327
#
#   superficie forestal total forestal arborizado  \
# 0                    469084              383689
# 1                    476769              392712
# 2                    474249              391888
# 3                    474170              391521
# 4                    475005              393851
#
#   pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 0                               85395                        219160
# 1                               84057                        215168
# 2                               82361                        216331
# 3                               82649                        216187
# 4                               81154                        214614
#
#   outras superficies
# 0             107083
# 1             103390
# 2             104746
# 3             104970
# 4             105708

# %%
co[co['municipio']=='NARON']
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies]
# Index: []

# %%
lu= pd.read_excel('/home/dsc/Galician_fires/Complementary data/Distribucion_terras/Distribucion_terras_lugo.xlsx')
lu.columns = map(lambda x: str(x).lower(), lu.columns)
lu['municipio'] = lu['municipio'].str.upper()
lu.head()
# Out:
#    codigo municipio   ano  superficie total do concello  \
# 0      27      LUGO  2006                        985600
# 1      27      LUGO  2007                        985600
# 2      27      LUGO  2008                        985600
# 3      27      LUGO  2009                        985600
# 4      27      LUGO  2010                        985600
#
#    superficie forestal total forestal arborizado  \
# 0                     627295              438944
# 1                     638059              447226
# 2                     636131              448611
# 3                     637676              451587
# 4                     638185              452688
#
#   pasteiro, pasteiro arbustivo e mato  superficie de cultivo e prado  \
# 0                              188351                         284423
# 1                              190833                         277201
# 2                              187521                         278413
# 3                              186089                         276677
# 4                              185498                         276133
#
#    outras superficies
# 0               73882
# 1               70340
# 2               71056
# 3               71247
# 4               71282

# %%
gal = [co, lu, ou, po]
gal = pd.concat(gal)
gal
# Out:
#       codigo municipio   ano superficie total do concello  \
# 0         15  A CORUÑA  2006                       795327
# 1         15  A CORUÑA  2007                       795327
# 2         15  A CORUÑA  2008                       795327
# 3         15  A CORUÑA  2009                       795327
# 4         15  A CORUÑA  2010                       795327
# ...      ...       ...   ...                          ...
# 1031   36057      VIGO  2015                        10906
# 1032   36057      VIGO  2016                        10906
# 1033   36057      VIGO  2017                        10906
# 1034   36057      VIGO  2018                        10906
# 1035   36057      VIGO  2019                        10906
#
#      superficie forestal total forestal arborizado  \
# 0                       469084              383689
# 1                       476769              392712
# 2                       474249              391888
# 3                       474170              391521
# 4                       475005              393851
# ...                        ...                 ...
# 1031                      3731                  ..
# 1032                      3727                  ..
# 1033                      3728                  ..
# 1034                      3728                  ..
# 1035                      3708                  ..
#
#      pasteiro, pasteiro arbustivo e mato superficie de cultivo e prado  \
# 0                                  85395                        219160
# 1                                  84057                        215168
# 2                                  82361                        216331
# 3                                  82649                        216187
# 4                                  81154                        214614
# ...                                  ...                           ...
# 1031                                  ..                          1316
# 1032                                  ..                          1315
# 1033                                  ..                          1314
# 1034                                  ..                          1312
# 1035                                  ..                          1314
#
#      outras superficies
# 0                107083
# 1                103390
# 2                104746
# 3                104970
# 4                105708
# ...                 ...
# 1031               5859
# 1032               5864
# 1033               5864
# 1034               5865
# 1035               5883
#
# [5236 rows x 9 columns]

# %%
gal.dtypes
# Out:
# codigo                                  int64
# municipio                              object
# ano                                     int64
# superficie total do concello           object
# superficie forestal total              object
# forestal arborizado                    object
# pasteiro, pasteiro arbustivo e mato    object
# superficie de cultivo e prado          object
# outras superficies                     object
# dtype: object

# %%
gal['codigo']=gal['codigo'].astype(str)

gal['idprovincia']=gal['codigo'].str[0:2]
gal['idmunicipio']=gal['codigo'].str[2:5]

# %%
gal['length'] = gal.codigo.str.len()

# %%
gal['codigo']= pd.to_numeric(gal['codigo'], downcast='integer')
gal.dtypes
# Out:
# <ipython-input-312-26c3222dc967>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gal['codigo']= pd.to_numeric(gal['codigo'], downcast='integer')
# codigo                                  int32
# municipio                              object
# ano                                     int64
# superficie total do concello           object
# superficie forestal total              object
# forestal arborizado                    object
# pasteiro, pasteiro arbustivo e mato    object
# superficie de cultivo e prado          object
# outras superficies                     object
# idprovincia                              int8
# idmunicipio                             int16
# length                                  int64
# dtype: object

# %%
gal['idmunicipio']= pd.to_numeric(gal['idmunicipio'], downcast='integer')
gal['idprovincia']= pd.to_numeric(gal['idprovincia'], downcast='integer')
# Out:
# <ipython-input-311-765d9e51fab4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gal['idmunicipio']= pd.to_numeric(gal['idmunicipio'], downcast='integer')
# <ipython-input-311-765d9e51fab4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gal['idprovincia']= pd.to_numeric(gal['idprovincia'], downcast='integer')

# %%
gal[gal['codigo']==36013]
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
prov=gal[gal.length != 5]
prov
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
gal=gal.drop(prov.index, axis=0)
gal.shape
# Out:
# (3024, 12)

# %%
prov.shape
# Out:
# (0, 12)

# %%
gal[gal['codigo']==36013]
# Out:
# Empty DataFrame
# Columns: [codigo, municipio, ano, superficie total do concello, superficie forestal total, forestal arborizado, pasteiro, pasteiro arbustivo e mato, superficie de cultivo e prado, outras superficies, idprovincia, idmunicipio, length]
# Index: []

# %%
df = pd.read_csv('/home/dsc/Galician_fires/fires-all.csv')
dfg = df[df['idcomunidad']==3]
dfg.dtypes
# Out:
# id                   int64
# superficie         float64
# fecha               object
# lat                float64
# lng                float64
# latlng_explicit      int64
# idcomunidad          int64
# idprovincia          int64
# idmunicipio          int64
# municipio           object
# causa                int64
# causa_supuesta     float64
# causa_desc           int64
# muertos            float64
# heridos            float64
# time_ctrl            int64
# time_ext             int64
# personal             int64
# medios               int64
# gastos             float64
# perdidas           float64
# dtype: object

# %%
dfg['ano']=dfg['fecha'].str[0:4]
dfg['ano']= pd.to_numeric(dfg['ano'], downcast='integer')
dfg.dtypes
# Out:
# <ipython-input-12-44d6d0d8867b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['ano']=dfg['fecha'].str[0:4]
# <ipython-input-12-44d6d0d8867b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['ano']= pd.to_numeric(dfg['ano'], downcast='integer')
# id                   int64
# superficie         float64
# fecha               object
# lat                float64
# lng                float64
# latlng_explicit      int64
# idcomunidad          int64
# idprovincia          int64
# idmunicipio          int64
# municipio           object
# causa                int64
# causa_supuesta     float64
# causa_desc           int64
# muertos            float64
# heridos            float64
# time_ctrl            int64
# time_ext             int64
# personal             int64
# medios               int64
# gastos             float64
# perdidas           float64
# ano                  int16
# dtype: object

# %%
dfg['idprovincia']=dfg['idprovincia'].astype(str)
dfg['idmunicipio']=dfg['idmunicipio'].astype(str)
# Out:
# <ipython-input-13-6b142f39d272>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['idprovincia']=dfg['idprovincia'].astype(str)
# <ipython-input-13-6b142f39d272>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['idmunicipio']=dfg['idmunicipio'].astype(str)

# %%
dfg.idmunicipio.str.len().unique()
# Out:
# array([2, 1, 3])

# %%
dfg['len']=dfg.idmunicipio.str.len()
dfg
# Out:
# <ipython-input-15-b629f5aa97be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['len']=dfg.idmunicipio.str.len()
#                id  superficie       fecha        lat       lng  \
# 1202   2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1203   2001150088        1.50  2001-02-24  42.936918 -9.114350
# 1204   2001150090        3.00  2001-02-25  42.643031 -8.939252
# 1205   2001150094        1.50  2001-02-25  43.186836 -8.685470
# 1206   2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 81478  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 81479  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 81480  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 81481  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 81482  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio  \
# 1202                 1            3          15          22
# 1203                 1            3          15          34
# 1204                 1            3          15          67
# 1205                 1            3          15          19
# 1206                 1            3          15          45
# ...                ...          ...         ...         ...
# 81478                1            3          36          50
# 81479                1            3          36          34
# 81480                1            3          36          16
# 81481                1            3          36          13
# 81482                1            3          36          52
#
#                    municipio  ...  muertos  heridos  time_ctrl  time_ext  \
# 1202                 CEDEIRA  ...      NaN      NaN        235       270
# 1203                 DUMBRÍA  ...      NaN      NaN        470       530
# 1204   POBRA DO CARAMIÑAL, A  ...      NaN      NaN        185       220
# 1205                CARBALLO  ...      NaN      NaN        125       135
# 1206               MAZARICOS  ...      NaN      NaN       1050      1051
# ...                      ...  ...      ...      ...        ...       ...
# 81478     SALVATERRA DE MIÑO  ...      NaN      NaN         92       486
# 81479              NEVES, AS  ...      NaN      NaN        404       420
# 81480                  DOZÓN  ...      NaN      NaN         87       194
# 81481                 COVELO  ...      NaN      NaN         89       428
# 81482                SILLEDA  ...      NaN      NaN         70        85
#
#        personal  medios  gastos  perdidas   ano  len
# 1202         14       2     NaN    7013.0  2001    2
# 1203         14       1     NaN    1497.0  2001    2
# 1204         14       3     NaN    1882.0  2001    2
# 1205          5       0     NaN    1028.0  2001    2
# 1206         14       1     NaN    3119.0  2001    2
# ...         ...     ...     ...       ...   ...  ...
# 81478        16       3  2012.0    6198.0  2015    2
# 81479        15       1  1509.0     430.0  2015    2
# 81480        18       3  1541.0       0.0  2015    2
# 81481        21       4  5805.0       0.0  2015    2
# 81482         7       0   908.0       0.0  2015    2
#
# [24587 rows x 23 columns]

# %%
y=[]
for x in (3-dfg['len']):
    y.append('0'*x)
dfg['ceros']=y
# Out:
# <ipython-input-16-298c8d34b603>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['ceros']=y

# %%
dfg['ceros'].unique()
# Out:
# array(['0', '00', ''], dtype=object)

# %%
dfg[dfg['ceros']=='00']
# Out:
#                id  superficie       fecha        lat       lng  \
# 1217   2001150213        1.70  2001-04-17  43.291593 -8.495562
# 1218   2001150214        1.40  2001-04-17  43.307140 -8.463079
# 1220   2001150227        1.50  2001-04-17  43.244306 -8.079977
# 1231   2001150255        1.10  2001-04-19  42.961596 -8.702523
# 1253   2001150337        4.50  2001-05-19  43.204208 -8.088987
# ...           ...         ...         ...        ...       ...
# 81464  2015360601        2.35  2015-08-09  42.587503 -8.717543
# 81465  2015360603        3.40  2015-08-09  42.600624 -8.673210
# 81467  2015360623        2.20  2015-08-09  42.104697 -8.312897
# 81474  2015360720        1.10  2015-09-03  42.130675 -8.310632
# 81477  2015360742        1.00  2015-09-06  42.140001 -8.321870
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio       municipio  \
# 1217                 1            3          15           5         ARTEIXO
# 1218                 1            3          15           5         ARTEIXO
# 1220                 1            3          15           3          ARANGA
# 1231                 1            3          15           7         BAÑA, A
# 1253                 1            3          15           3          ARANGA
# ...                ...          ...         ...         ...             ...
# 81464                1            3          36           5  CALDAS DE REIS
# 81465                1            3          36           5  CALDAS DE REIS
# 81467                1            3          36           1            ARBO
# 81474                1            3          36           1            ARBO
# 81477                1            3          36           1            ARBO
#
#        ...  heridos  time_ctrl  time_ext  personal  medios  gastos  perdidas  \
# 1217   ...      NaN        200       245         9       1     NaN    2175.0
# 1218   ...      NaN        125       170        16       2     NaN     541.0
# 1220   ...      NaN        125       135         9       1     NaN    1857.0
# 1231   ...      NaN        110       170         6       1     NaN    1015.0
# 1253   ...      NaN        320       550        24       1     NaN    5030.0
# ...    ...      ...        ...       ...       ...     ...     ...       ...
# 81464  ...      NaN        206       419        33       3  4067.0    3534.0
# 81465  ...      NaN        359       834        32       6  5381.0    5544.0
# 81467  ...      NaN        145       328        14       0  2649.0    8884.0
# 81474  ...      NaN        112       274        39       6  9897.0    1068.0
# 81477  ...      NaN        335       495        14       3  3071.0    1513.0
#
#         ano  len  ceros
# 1217   2001    1     00
# 1218   2001    1     00
# 1220   2001    1     00
# 1231   2001    1     00
# 1253   2001    1     00
# ...     ...  ...    ...
# 81464  2015    1     00
# 81465  2015    1     00
# 81467  2015    1     00
# 81474  2015    1     00
# 81477  2015    1     00
#
# [2338 rows x 24 columns]

# %%
dfg['codigo']=dfg.idprovincia.astype(str)+dfg.ceros.astype(str)+dfg.idmunicipio.astype(str)
# Out:
# <ipython-input-19-d6ff3fdfc5d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['codigo']=dfg.idprovincia.astype(str)+dfg.ceros.astype(str)+dfg.idmunicipio.astype(str)

# %%
dfg.codigo.str.len().unique()
# Out:
# array([5])

# %%
dfg
# Out:
#                id  superficie       fecha        lat       lng  \
# 1202   2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1203   2001150088        1.50  2001-02-24  42.936918 -9.114350
# 1204   2001150090        3.00  2001-02-25  42.643031 -8.939252
# 1205   2001150094        1.50  2001-02-25  43.186836 -8.685470
# 1206   2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 81478  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 81479  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 81480  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 81481  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 81482  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio  \
# 1202                 1            3          15          22
# 1203                 1            3          15          34
# 1204                 1            3          15          67
# 1205                 1            3          15          19
# 1206                 1            3          15          45
# ...                ...          ...         ...         ...
# 81478                1            3          36          50
# 81479                1            3          36          34
# 81480                1            3          36          16
# 81481                1            3          36          13
# 81482                1            3          36          52
#
#                    municipio  ...  time_ctrl  time_ext  personal  medios  \
# 1202                 CEDEIRA  ...        235       270        14       2
# 1203                 DUMBRÍA  ...        470       530        14       1
# 1204   POBRA DO CARAMIÑAL, A  ...        185       220        14       3
# 1205                CARBALLO  ...        125       135         5       0
# 1206               MAZARICOS  ...       1050      1051        14       1
# ...                      ...  ...        ...       ...       ...     ...
# 81478     SALVATERRA DE MIÑO  ...         92       486        16       3
# 81479              NEVES, AS  ...        404       420        15       1
# 81480                  DOZÓN  ...         87       194        18       3
# 81481                 COVELO  ...         89       428        21       4
# 81482                SILLEDA  ...         70        85         7       0
#
#        gastos  perdidas   ano  len  ceros  codigo
# 1202      NaN    7013.0  2001    2      0   15022
# 1203      NaN    1497.0  2001    2      0   15034
# 1204      NaN    1882.0  2001    2      0   15067
# 1205      NaN    1028.0  2001    2      0   15019
# 1206      NaN    3119.0  2001    2      0   15045
# ...       ...       ...   ...  ...    ...     ...
# 81478  2012.0    6198.0  2015    2      0   36050
# 81479  1509.0     430.0  2015    2      0   36034
# 81480  1541.0       0.0  2015    2      0   36016
# 81481  5805.0       0.0  2015    2      0   36013
# 81482   908.0       0.0  2015    2      0   36052
#
# [24587 rows x 25 columns]

# %%
dfg.dtypes
# Out:
# id                   int64
# superficie         float64
# fecha               object
# lat                float64
# lng                float64
# latlng_explicit      int64
# idcomunidad          int64
# idprovincia         object
# idmunicipio         object
# municipio           object
# causa                int64
# causa_supuesta     float64
# causa_desc           int64
# muertos            float64
# heridos            float64
# time_ctrl            int64
# time_ext             int64
# personal             int64
# medios               int64
# gastos             float64
# perdidas           float64
# ano                  int16
# len                  int64
# ceros               object
# codigo              object
# dtype: object

# %%
gal.dtypes
# Out:
# codigo                                  int64
# municipio                              object
# ano                                     int64
# superficie total do concello           object
# superficie forestal total              object
# forestal arborizado                    object
# pasteiro, pasteiro arbustivo e mato    object
# superficie de cultivo e prado          object
# outras superficies                     object
# dtype: object

# %%
dfg['codigo']= pd.to_numeric(dfg['codigo'], downcast='integer')
# Out:
# <ipython-input-28-95e879571f9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['codigo']= pd.to_numeric(dfg['codigo'], downcast='integer')

# %%
gz = pd.merge(dfg, gal, on = ['codigo','ano'], how ='left')
gz
# Out:
#                id  superficie       fecha        lat       lng  \
# 0      2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1      2001150088        1.50  2001-02-24  42.936918 -9.114350
# 2      2001150090        3.00  2001-02-25  42.643031 -8.939252
# 3      2001150094        1.50  2001-02-25  43.186836 -8.685470
# 4      2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 24591  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 24592  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 24593  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 24594  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 24595  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio  \
# 0                    1            3          15          22
# 1                    1            3          15          34
# 2                    1            3          15          67
# 3                    1            3          15          19
# 4                    1            3          15          45
# ...                ...          ...         ...         ...
# 24591                1            3          36          50
# 24592                1            3          36          34
# 24593                1            3          36          16
# 24594                1            3          36          13
# 24595                1            3          36          52
#
#                  municipio_x  ...  len  ceros  codigo         municipio_y  \
# 0                    CEDEIRA  ...    2      0   15022                 NaN
# 1                    DUMBRÍA  ...    2      0   15034                 NaN
# 2      POBRA DO CARAMIÑAL, A  ...    2      0   15067                 NaN
# 3                   CARBALLO  ...    2      0   15019                 NaN
# 4                  MAZARICOS  ...    2      0   15045                 NaN
# ...                      ...  ...  ...    ...     ...                 ...
# 24591     SALVATERRA DE MIÑO  ...    2      0   36050  SALVATERRA DE MIÑO
# 24592              NEVES, AS  ...    2      0   36034            AS NEVES
# 24593                  DOZÓN  ...    2      0   36016               DOZÓN
# 24594                 COVELO  ...    2      0   36013              COVELO
# 24595                SILLEDA  ...    2      0   36052             SILLEDA
#
#        superficie total do concello  superficie forestal total  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 24591                          6254                       3481
# 24592                          6550                       4580
# 24593                          7423                       4702
# 24594                         13190                      10256
# 24595                         16796                       7443
#
#        forestal arborizado  pasteiro, pasteiro arbustivo e mato  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
# ...                    ...                                  ...
# 24591                   ..                                   ..
# 24592                   ..                                   ..
# 24593                   ..                                   ..
# 24594                   ..                                   ..
# 24595                   ..                                   ..
#
#        superficie de cultivo e prado  outras superficies
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
# ...                              ...                 ...
# 24591                           1258                1515
# 24592                            774                1196
# 24593                           2222                 499
# 24594                           1677                1258
# 24595                           6867                2486
#
# [24596 rows x 32 columns]

# %%
gz.columns
# Out:
# Index(['id', 'superficie', 'fecha', 'lat', 'lng', 'latlng_explicit',
#        'idcomunidad', 'idprovincia', 'idmunicipio', 'municipio_x', 'causa',
#        'causa_supuesta', 'causa_desc', 'muertos', 'heridos', 'time_ctrl',
#        'time_ext', 'personal', 'medios', 'gastos', 'perdidas', 'ano', 'codigo',
#        'municipio_y', 'superficie total do concello',
#        'superficie forestal total', 'forestal arborizado',
#        'pasteiro, pasteiro arbustivo e mato', 'superficie de cultivo e prado',
#        'outras superficies', 'length'],
#       dtype='object')

# %%
gz[['id', 'fecha', 'lat', 'lng',
       'idcomunidad', 'idprovincia', 'idmunicipio', 'municipio_x', 'ano', 'codigo',
       'municipio_y', 'superficie total do concello',
       'superficie forestal total', 'forestal arborizado']][gz['ano']==2008]
# Out:
#                id       fecha        lat       lng  idcomunidad idprovincia  \
# 16984  2008150001  2008-01-27  42.971510 -7.953572            3          15
# 16985  2008150007  2008-02-10  43.206767 -8.158413            3          15
# 16986  2008150008  2008-02-10  42.971510 -7.953572            3          15
# 16987  2008150011  2008-02-12  42.686091 -8.785263            3          15
# 16988  2008150013  2008-02-13  43.287868 -8.068270            3          15
# ...           ...         ...        ...       ...          ...         ...
# 17691  2008360682  2008-12-24  42.627302 -7.934374            3          36
# 17692  2008360685  2008-12-25  42.679228 -8.257182            3          36
# 17693  2008360688  2008-12-26  42.681691 -8.251026            3          36
# 17694  2008360691  2008-12-26  42.636434 -8.228724            3          36
# 17695  2008360693  2008-12-26  42.340583 -8.309023            3          36
#
#       idmunicipio   municipio_x   ano  codigo   municipio_y  \
# 16984          83        TOQUES  2008   15083        TOQUES
# 16985          63  OZA DOS RÍOS  2008   15063  OZA DOS RÌOS
# 16986          83        TOQUES  2008   15083        TOQUES
# 16987          72        RIANXO  2008   15072        RIANXO
# 16988          39        IRIXOA  2008   15039        IRIXOA
# ...           ...           ...   ...     ...           ...
# 17691          47       RODEIRO  2008   36047       RODEIRO
# 17692          52       SILLEDA  2008   36052       SILLEDA
# 17693          52       SILLEDA  2008   36052       SILLEDA
# 17694          52       SILLEDA  2008   36052       SILLEDA
# 17695          13        COVELO  2008   36013        COVELO
#
#       superficie total do concello superficie forestal total  \
# 16984                         7792                      5595
# 16985                         7192                      4346
# 16986                         7792                      5595
# 16987                         5885                      3650
# 16988                         6823                      4788
# ...                            ...                       ...
# 17691                        15490                      7853
# 17692                        16796                      7787
# 17693                        16796                      7787
# 17694                        16796                      7787
# 17695                        12531                     10318
#
#       forestal arborizado
# 16984                1823
# 16985                3172
# 16986                1823
# 16987                3265
# 16988                4169
# ...                   ...
# 17691                3593
# 17692                5671
# 17693                5671
# 17694                5671
# 17695                3785
#
# [712 rows x 14 columns]

# %%
gz[gz['ano']>2006 & gz['superficie total do concello'].isna()]
# Out:
#                id  superficie       fecha        lat       lng  \
# 0      2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1      2001150088        1.50  2001-02-24  42.936918 -9.114350
# 2      2001150090        3.00  2001-02-25  42.643031 -8.939252
# 3      2001150094        1.50  2001-02-25  43.186836 -8.685470
# 4      2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 24591  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 24592  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 24593  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 24594  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 24595  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad idprovincia idmunicipio  \
# 0                    1            3          15          22
# 1                    1            3          15          34
# 2                    1            3          15          67
# 3                    1            3          15          19
# 4                    1            3          15          45
# ...                ...          ...         ...         ...
# 24591                1            3          36          50
# 24592                1            3          36          34
# 24593                1            3          36          16
# 24594                1            3          36          13
# 24595                1            3          36          52
#
#                  municipio_x  ...  len  ceros  codigo         municipio_y  \
# 0                    CEDEIRA  ...    2      0   15022                 NaN
# 1                    DUMBRÍA  ...    2      0   15034                 NaN
# 2      POBRA DO CARAMIÑAL, A  ...    2      0   15067                 NaN
# 3                   CARBALLO  ...    2      0   15019                 NaN
# 4                  MAZARICOS  ...    2      0   15045                 NaN
# ...                      ...  ...  ...    ...     ...                 ...
# 24591     SALVATERRA DE MIÑO  ...    2      0   36050  SALVATERRA DE MIÑO
# 24592              NEVES, AS  ...    2      0   36034            AS NEVES
# 24593                  DOZÓN  ...    2      0   36016               DOZÓN
# 24594                 COVELO  ...    2      0   36013              COVELO
# 24595                SILLEDA  ...    2      0   36052             SILLEDA
#
#        superficie total do concello  superficie forestal total  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 24591                          6254                       3481
# 24592                          6550                       4580
# 24593                          7423                       4702
# 24594                         13190                      10256
# 24595                         16796                       7443
#
#        forestal arborizado  pasteiro, pasteiro arbustivo e mato  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
# ...                    ...                                  ...
# 24591                   ..                                   ..
# 24592                   ..                                   ..
# 24593                   ..                                   ..
# 24594                   ..                                   ..
# 24595                   ..                                   ..
#
#        superficie de cultivo e prado  outras superficies
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
# ...                              ...                 ...
# 24591                           1258                1515
# 24592                            774                1196
# 24593                           2222                 499
# 24594                           1677                1258
# 24595                           6867                2486
#
# [24596 rows x 32 columns]
