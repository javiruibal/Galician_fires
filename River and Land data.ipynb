# %%
import pandas as pd

# %%
dfl = pd.read_excel('Distribucion_terras_lugo.xlsx')
dfl['Municipio']=dfl['Municipio'].str.upper()
dfl
# Out:
#        Code     Municipio   Año  Superficie total do concello  \
# 0        27  LUGO (TOTAL)  2006                        985600
# 1        27  LUGO (TOTAL)  2007                        985600
# 2        27  LUGO (TOTAL)  2008                        985600
# 3        27  LUGO (TOTAL)  2009                        985600
# 4        27  LUGO (TOTAL)  2010                        985600
# ...     ...           ...   ...                           ...
# 1129  27040  PALAS DE REI  2015                         19968
# 1130  27040  PALAS DE REI  2016                         19968
# 1131  27040  PALAS DE REI  2017                         19968
# 1132  27040  PALAS DE REI  2018                         19968
# 1133  27040  PALAS DE REI  2019                         19968
#
#       Superficie forestal total Forestal arborizado  \
# 0                        627295              438944
# 1                        638059              447226
# 2                        636131              448611
# ...

# %%
dfl.columns = map(lambda x: str(x).lower(), dfl.columns)

# %%
dfl['municipio'].unique()
# Out:
# array(['LUGO (TOTAL)', 'OS ANCARES', 'BARALLA', 'BECERRE·', 'CERVANTES',
#        'NAVIA DE SUARNA', 'NOGAIS', 'PEDRAFITA DO CEBREIRO', 'CHANTADA',
#        'CARBALLEDO', 'TABOADA', 'A FONSAGRADA', 'BALEIRA',
#        'NEGUEIRA DE MUÒIZ', 'LUGO', 'CASTROVERDE', 'O CORGO', 'FRIOL',
#        'GUNTÌN', 'OUTEIRO DE REI', 'PORTOMARÌN', 'RABADE',
#        'A MARIÑA CENTRAL', 'ALFOZ', 'BURELA', 'FOZ', 'LOURENZ·',
#        'MONDOÑEDO', 'VALADOURO', 'A MARIÑA OCCIDENTAL', 'CERVO', 'OUROL',
#        'VICEDO', 'VIVEIRO', 'XOVE', 'A MARIÑA ORIENTAL', 'BARREIROS',
#        'PONTENOVA', 'RIBADEO', 'TRABADA', 'MEIRA', 'POL',
#        'RIBEIRA DE PIQUÌN', 'RIOTORTO', 'QUIROGA', 'FOLGOSO DO COUREL',
#        'RIBAS DE SIL', 'SARRIA', 'INCIO', 'LÁNCARA', 'PARADELA',
#        'O P·RAMO', 'SAMOS', 'TRIACASTELA', 'TERRA CHÁ', 'ABADÌN',
#        'BEGONTE', 'CASTRO DE REI', 'COSPEITO', 'GUITIRIZ', 'MURAS',
#        'A PASTORIZA', 'VILALBA', 'XERMADE', 'TERRA DE LEMOS', 'BÛVEDA',
# ...

# %%
dfc = pd.read_excel('Distribucion_terras_coruña.xlsx')
dfc['Municipio']=dfc['Municipio'].str.upper()
dfc
# Out:
#      Codigo    Municipio   Ano Superficie total do concello  \
# 0     Total     A CORUÑA  2006                       795327
# 1        15     A CORUÑA  2007                       795327
# 2        15     A CORUÑA  2008                       795327
# 3        15     A CORUÑA  2009                       795327
# 4        15     A CORUÑA  2010                       795327
# ...     ...          ...   ...                          ...
# 1591  15077  SANTA COMBA  2015                        20370
# 1592  15077  SANTA COMBA  2016                        20370
# 1593  15077  SANTA COMBA  2017                        20370
# 1594  15077  SANTA COMBA  2018                        20370
# 1595  15077  SANTA COMBA  2019                        20370
#
#      Superficie forestal total Forestal arborizado  \
# 0                       469084              383689
# 1                       476769              392712
# 2                       474249              391888
# ...

# %%
dfc.columns = map(lambda x: str(x).lower(), dfc.columns)

# %%
dfc['municipio'].unique()
# Out:
# array(['A CORUÑA', 'ARZÚA', 'BOIMORTO', 'O PINO', 'TOURO', 'BARBANZA',
#        'BOIRO', 'A POBRA DO CARAMIÑAL', 'RIANXO', 'RIBEIRA', 'A BARCALA',
#        'A BAÒA', 'NEGREIRA', 'BERGANTIÑOS', 'CABANA DE BERGANTIÑOS',
#        'CARBALLO', 'CORISTANCO', 'A LARACHA', 'LAXE',
#        'MALPICA DE BERGANTIÑOS', 'MALPICA DE BERGANTIÒOS', 'PONTECESO',
#        'BETANZOS', 'ARANGA', 'CESURAS', 'COIRÛS', 'CURTIS', 'IRIXOA',
#        'MIÒO', 'OZA DOS RÌOS', 'OZA-CESURAS', 'PADERNE', 'VILARMAIOR',
#        'VILASANTAR', 'ABEGONDO', 'ARTEIXO', 'BERGONDO', 'CAMBRE',
#        'CARRAL', 'CULLEREDO', 'OLEIROS', 'SADA', 'EUME', 'CABANAS',
#        'A CAPELA', 'MONFERO', 'PONTEDEUME',
#        'AS PONTES DE GARCÌA RODRÌGUEZ', 'FERROL', 'ARES', 'CEDEIRA',
#        'FENE', 'MOECHE', 'MUGARDOS', 'NARÓN', 'NEDA', 'SAN SADURNIÑO',
#        'AS SOMOZAS', 'VALDOVIÑO', 'FISTERRA', 'CEE', 'CORCUBIÓN',
#        'DUMBRÌA', 'MUXÍA', 'MUROS', 'CARNOTA', 'NOIA', 'LOUSAME', 'OUTES',
# ...

# %%
rios = pd.read_excel('/home/dsc/Galician_fires/Complementary data/RIOS_GALICIA.xlsx')
rios
# Out:
#     Provincia              Municipio      Rio  Longitud (Km) Afluentes  \
# 0    A Coruña               Soandres  Anllóns             55       NaN
# 1    A Coruña                Laracha  Anllóns             55       NaN
# 2    A Coruña                Canduas  Anllóns             55       NaN
# 3    A Coruña                Cerdeda  Anllóns             55       NaN
# 4    A Coruña               Carballo  Anllóns             55       NaN
# ..        ...                    ...      ...            ...       ...
# 236      Lugo      Monforte de Lemos      Mao             30       NaN
# 237      Lugo  Pedrafita do Cebreiro      Lor             50       NaN
# 238      Lugo      Folgoso do Courel      Lor             50       NaN
# 239      Lugo     A Pobra do Brollón      Lor             50       NaN
# 240      Lugo                Quiroga      Lor             50       NaN
#
#     Afluente de
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...

# %%
rios.columns = map(lambda x: str(x).lower(), rios.columns)

# %%
rios['provincia']=rios['provincia'].str.upper()
rios['municipio']=rios['municipio'].str.upper()
rios['rio']=rios['rio'].str.upper()
rios
# Out:
#     provincia              municipio      rio  longitud (km) afluentes  \
# 0    A CORUÑA               SOANDRES  ANLLÓNS             55       NaN
# 1    A CORUÑA                LARACHA  ANLLÓNS             55       NaN
# 2    A CORUÑA                CANDUAS  ANLLÓNS             55       NaN
# 3    A CORUÑA                CERDEDA  ANLLÓNS             55       NaN
# 4    A CORUÑA               CARBALLO  ANLLÓNS             55       NaN
# ..        ...                    ...      ...            ...       ...
# 236      LUGO      MONFORTE DE LEMOS      MAO             30       NaN
# 237      LUGO  PEDRAFITA DO CEBREIRO      LOR             50       NaN
# 238      LUGO      FOLGOSO DO COUREL      LOR             50       NaN
# 239      LUGO     A POBRA DO BROLLÓN      LOR             50       NaN
# 240      LUGO                QUIROGA      LOR             50       NaN
#
#     afluente de
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...

# %%
rios['Municipio'].unique()
# Out:
# array(['SOANDRES', 'LARACHA', 'CANDUAS', 'CERDEDA', 'CARBALLO',
#        'CORISTANCO', 'PONTECESO', 'CABANA DE BERGANTIÑOS', 'ABADÍN',
#        'XERMADE', 'MURAS', 'AS PONTES DE GARCÍA RODRÍGUEZ', 'MONFERO',
#        'A CAPELA', 'CABANAS', 'PONTEDEUME', 'LOURENZÁ', 'TRABADA',
#        'BARREIROS', 'RIBADEO', 'SOMOZAS', 'MOECHE', 'SAN SADURNIÑO',
#        'XUBIA', 'NARON', 'NEDA', 'PONTEVEDRA', 'FORCAREI', 'CERDEDO',
#        'CAMPO LAMEIRO', 'COTOBADE', 'LIMIA', 'A BAIXA LIMIA',
#        'XINZO DE LIMIA', 'SOBRADO DOS MONXES', 'ARANGA', 'CURTIS',
#        'IRIXOA', 'COIRÓS', 'PADERNE', 'BETANZOS', 'OZA-CESURAS',
#        'ABEGONDO', 'BERGONDO', 'CAMBRE', 'CULLEREDO', 'OLEIROS',
#        'SOBRADO', 'VILASANTAR', 'BOIMORTO', 'MESÍA', 'FRADES', 'ARZÚA',
#        'O PINO', 'OROSO', 'ORDES', 'TRAZO', 'TORDOIA',
#        'SANTIAGO DE COMPOSTELA', 'VAL DO DUBRA', 'AMES', 'TROITOSENDRE',
#        'BRIÓN', 'NEGREIRA', 'OUTES', 'NOIA', 'ANTAS DE ULLA',
# ...

# %%
df = pd.read_csv('/home/dsc/Galician_fires/fires-all.csv')
df = df[df['idcomunidad']==3]
df
# Out:
#                id  superficie       fecha        lat       lng  \
# 1202   2001150021        5.00  2001-02-20  43.703581 -8.038777
# 1203   2001150088        1.50  2001-02-24  42.936918 -9.114350
# 1204   2001150090        3.00  2001-02-25  42.643031 -8.939252
# 1205   2001150094        1.50  2001-02-25  43.186836 -8.685470
# 1206   2001150111        3.80  2001-02-25  42.917476 -9.082862
# ...           ...         ...         ...        ...       ...
# 81478  2015360747        1.45  2015-09-06  42.103959 -8.522512
# 81479  2015360751        1.00  2015-09-06  42.157695 -8.397080
# 81480  2015360770        5.94  2015-09-08  42.554722 -8.018586
# 81481  2015360794        3.20  2015-09-28  42.243441 -8.322375
# 81482  2015360819        2.26  2015-12-27  42.658303 -8.268949
#
#        latlng_explicit  idcomunidad  idprovincia  idmunicipio  \
# 1202                 1            3           15           22
# 1203                 1            3           15           34
# ...

# %%
df['municipio'].unique()
# Out:
# array(['CEDEIRA', 'DUMBRÍA', 'POBRA DO CARAMIÑAL, A', 'CARBALLO',
#        'MAZARICOS', 'LOUSAME', 'MUXÍA', 'OUTES', 'CEE', 'MONFERO',
#        'PINO, O', 'SAN SADURNIÑO', 'ARTEIXO', 'NOIA', 'ARANGA', 'BRIÓN',
#        'SANTIAGO DE COMPOSTELA', 'VILASANTAR', 'TEO',
#        'BOQUEIXÓN-CASANOVA', 'BOIRO', 'BAÑA, A', 'SADA', 'NEGREIRA',
#        'PADRÓN', 'SANTA COMBA', 'VIMIANZO', 'CABANA DE BERGANTIÑOS',
#        'FISTERRA', 'ZAS', 'PADERNE', 'NEDA', 'ORDES', 'FRADES', 'TOURO',
#        'VAL DO DUBRA', 'CULLEREDO', 'RIANXO', 'MIÑO', 'CORISTANCO',
#        'OLEIROS', 'VILARMAIOR', 'OZA DOS RÍOS', 'CURTIS', 'NARÓN',
#        'MELIDE', 'VALDOVIÑO', 'CESURAS', 'AMES', 'TORDOIA', 'CORUÑA, A',
#        'LARACHA, A', 'RIBEIRA', 'FERROL', 'PORTO DO SON', 'MESÍA', 'ROIS',
#        'TOQUES', 'CARNOTA', 'MUROS', 'ARES', 'CARRAL', 'FENE', 'ABEGONDO',
#        'CAMARIÑAS', 'LAXE', 'MALPICA DE BERGANTIÑOS', 'SANTISO', 'TRAZO',
#        'PONTECESO', 'ARZÚA', 'SOMOZAS, AS', 'DODRO',
# ...
